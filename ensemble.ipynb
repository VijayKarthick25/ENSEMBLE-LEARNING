# %%
import pandas as pd
test_set=pd.read_csv("/content/test_preprocessed.csv")
train_set=pd.read_csv("/content/train_preprocessed.csv")
test_set
# Out:
#      PassengerId  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0            892       3    0    2     0         2      1        1          6
# 1            893       3    1    2     0         0      3        0          6
# 2            894       2    0    3     1         2      1        1          6
# 3            895       3    0    1     1         0      1        1          3
# 4            896       3    1    1     1         0      3        0          3
# ..           ...     ...  ...  ...   ...       ...    ...      ...        ...
# 413         1305       3    0    1     1         0      1        1          3
# 414         1306       1    1    2     3         1      5        1          2
# 415         1307       3    0    2     0         0      1        1          6
# 416         1308       3    0    1     1         0      1        1          3
# 417         1309       3    0    1     2         1      4        0          3
#
# [418 rows x 9 columns]

# %%
train_set
# Out:
#      Survived  Pclass  Sex  Age  Fare  Embarked  Title  IsAlone  Age*Class
# 0           0       3    0    1     0         0      1        0          3
# 1           1       1    1    2     3         1      3        0          2
# 2           1       3    1    1     1         0      2        1          3
# 3           1       1    1    2     3         0      3        0          2
# 4           0       3    0    2     1         0      1        1          6
# ..        ...     ...  ...  ...   ...       ...    ...      ...        ...
# 886         0       2    0    1     1         0      5        1          2
# 887         1       1    1    1     2         0      2        1          1
# 888         0       3    1    1     2         0      2        0          3
# 889         1       1    0    1     2         1      1        1          1
# 890         0       3    0    1     0         2      1        1          3
#
# [891 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(train_set.drop("Survived",axis=1),train_set["Survived"],test_size=0.2,random_state=42)

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
print(y_train)
# Out:
# 331    0
# 733    0
# 382    0
# 704    0
# 813    0
#       ..
# 106    1
# 270    0
# 860    0
# 435    1
# 102    0
# Name: Survived, Length: 712, dtype: int64

# %%
print(y_test)
# Out:
# 709    1
# 439    0
# 840    0
# 720    1
# 39     1
#       ..
# 433    0
# 773    0
# 25     1
# 84     1
# 10     1
# Name: Survived, Length: 179, dtype: int64

# %%
def evaluation(model,x_train,y_train,x_test,y_test,train=True):
  if train:
    print("train result:\n")
    # print("accuracyscore:{0:4f}\n".format())
    print("classificationreport:\n",(classification_report(y_train,model.predict(x_train))))
    print("confusionmatrix:\n",(confusion_matrix(y_train,model.predict(x_train))))
  elif train==False:
     print("test result:\n")
     print("classificationreport:\n",classification_report(y_test,model.predict(x_test)))
     print("confusionmatrix:\n",confusion_matrix(y_test,model.predict(x_test)))

# %%
from sklearn.tree import DecisionTreeClassifier
dtclassifier=DecisionTreeClassifier()
dtclassifier.fit(x_train,y_train)
evaluation(dtclassifier,x_train,y_train,x_test,y_test,train=True)
# Out:
# train result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       444
#            1       0.87      0.78      0.82       268
#
#     accuracy                           0.87       712
#    macro avg       0.87      0.85      0.86       712
# weighted avg       0.87      0.87      0.87       712
#
# confusionmatrix:
#  [[413  31]
#  [ 60 208]]

# %%
evaluation(dtclassifier,x_train,y_train,x_test,y_test,train=False)
# Out:
# test result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.85      0.84      0.85       105
#            1       0.78      0.80      0.79        74
#
#     accuracy                           0.82       179
#    macro avg       0.82      0.82      0.82       179
# weighted avg       0.82      0.82      0.82       179
#
# confusionmatrix:
#  [[88 17]
#  [15 59]]

# %% [markdown]
# train_test_split are done
#
# a basic algorithm decision tree classifier has done
# #       the next step is to enhance it by
# #          *bagging
# #          *boosting
# #          *stacking
#        1.bagging: eg:- random forest
#             *estimator
#                (decides where the bagging method should implied)
#             *n_estimator= 500,1000 etc..,
#                (number of trees should form for the perfection and avoiding overfitting of models)
#             *bootstrap
#                (selecting the majority of treesplit answers)
#             *n_jobs= -1 or 1
#                 (n_jobs=-1 = the system to use all the available cpu cores or procressiors
#
#                  n_jobs=1 = indicates that operations should executed sequentially using only a single processor or thread no parallelism)
#              eg:- random forest:
#                         from sklearn.ensemble import RandomForestClassifier
#                         from sklearn.model_selection import cross_val_predict,cross_val_score,GridSearchCV
#                          finding the optimal parameter values from a given set of parameters in a grid.
#                          runs in sequence to avoid mistakes of trees
#          2.boosting:
#              *adaboosting
#              *xgboosting- advanced version of adaboosting
#                ( max_depth=5,
#                  n_estimators=1000,
#                  learning_rate=0.3,
#                  n_jobs=-1
#                 )
#          3.stacking:
#              providing output from weak learners ie.,
#                 0level-->metalevel

# %% [markdown]
# # **bagging**

# %% [markdown]
# bootstrap= voting
#
# n_jobs=-1 = the system to use all the available cpu cores or procressiors
#
# n_jobs=1 = indicates that operations should executed sequentially using only a single processor or thread no parallelism
#
# n_estimators= number of decision trees that will be constructed in the forest(improves accuracy and overfitting)

# %%
from sklearn.ensemble import BaggingClassifier
bgclassifier=BaggingClassifier(estimator=dtclassifier,n_estimators=1000,bootstrap=True,n_jobs=1,random_state=42)
bgclassifier.fit(x_train,y_train)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=1000,
#                   n_jobs=1, random_state=42)

# %%
evaluation(bgclassifier,x_train,y_train,x_test,y_test,train=True)
# Out:
# train result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90       444
#            1       0.86      0.78      0.82       268
#
#     accuracy                           0.87       712
#    macro avg       0.87      0.85      0.86       712
# weighted avg       0.87      0.87      0.87       712
#
# confusionmatrix:
#  [[411  33]
#  [ 58 210]]

# %%
evaluation(bgclassifier,x_train,y_train,x_test,y_test,train=False)
# Out:
# test result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84       105
#            1       0.77      0.78      0.78        74
#
#     accuracy                           0.82       179
#    macro avg       0.81      0.81      0.81       179
# weighted avg       0.82      0.82      0.82       179
#
# confusionmatrix:
#  [[88 17]
#  [16 58]]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_predict,cross_val_score,GridSearchCV
rfclassifier=RandomForestClassifier()
rfclassifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf_params={
    "max_depth":[3,None],
    "min_samples_split":[2,3,10],
    "min_samples_leaf":[1,3,10],
    "bootstrap":[True,False],
    "criterion":["gini","entropy"]

 }

# %%
grid_search =GridSearchCV(rfclassifier,rf_params,n_jobs=-1,cv=5,scoring="accuracy")

# %%
grid_search.estimator.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, None], 'min_samples_leaf': [1, 3, 10],
#                          'min_samples_split': [2, 3, 10]},
#              scoring='accuracy')

# %%
evaluation(grid_search,x_train,y_train,x_test,y_test,train=True)
# Out:
# train result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89       444
#            1       0.85      0.77      0.81       268
#
#     accuracy                           0.86       712
#    macro avg       0.86      0.84      0.85       712
# weighted avg       0.86      0.86      0.86       712
#
# confusionmatrix:
#  [[408  36]
#  [ 62 206]]

# %%
evaluation(grid_search,x_train,y_train,x_test,y_test,train=False)
# Out:
# test result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84       105
#            1       0.77      0.78      0.78        74
#
#     accuracy                           0.82       179
#    macro avg       0.81      0.81      0.81       179
# weighted avg       0.82      0.82      0.82       179
#
# confusionmatrix:
#  [[88 17]
#  [16 58]]

# %% [markdown]
# boosting

# %%
from sklearn.ensemble import AdaBoostClassifier
abclassifier=AdaBoostClassifier()
abclassifier.fit(x_train,y_train)
# Out:
# AdaBoostClassifier()

# %%
evaluation(abclassifier,x_train,y_train,x_test,y_test,train=True)
# Out:
# train result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       444
#            1       0.75      0.72      0.74       268
#
#     accuracy                           0.80       712
#    macro avg       0.79      0.79      0.79       712
# weighted avg       0.80      0.80      0.80       712
#
# confusionmatrix:
#  [[380  64]
#  [ 75 193]]

# %%
evaluation(abclassifier,x_train,y_train,x_test,y_test,train=False)
# Out:
# test result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83       105
#            1       0.77      0.76      0.76        74
#
#     accuracy                           0.80       179
#    macro avg       0.80      0.80      0.80       179
# weighted avg       0.80      0.80      0.80       179
#
# confusionmatrix:
#  [[88 17]
#  [18 56]]

# %%
import xgboost as xg
xgb=xg.XGBClassifier(
    max_depth=5,
    n_estimators=1000,
    learning_rate=0.3,
    n_jobs=-1

)
xgb.fit(x_train,y_train)
# learningrete range=0.05-0.1
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.3, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#               n_jobs=-1, num_parallel_tree=None, ...)

# %%
evaluation(xgb,x_train,y_train,x_test,y_test,train=True)
# Out:
# train result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       444
#            1       0.86      0.78      0.82       268
#
#     accuracy                           0.87       712
#    macro avg       0.87      0.85      0.86       712
# weighted avg       0.87      0.87      0.87       712
#
# confusionmatrix:
#  [[411  33]
#  [ 59 209]]

# %%
evaluation(xgb,x_train,y_train,x_test,y_test,train=False)
# Out:
# test result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.84      0.83      0.84       105
#            1       0.76      0.78      0.77        74
#
#     accuracy                           0.81       179
#    macro avg       0.80      0.81      0.80       179
# weighted avg       0.81      0.81      0.81       179
#
# confusionmatrix:
#  [[87 18]
#  [16 58]]

# %%
y_pred=xgb.predict(test_set.drop("PassengerId",axis=1))
actualpred=pd.DataFrame({
    "PassengerId":test_set["PassengerId"],
    "Survived":y_pred
})
actualpred.to_csv("file.csv",index=False)

# %% [markdown]
# Stacking

# %%
sta=pd.DataFrame()

# %%
sta["decision"]=pd.DataFrame(dtclassifier.predict_proba(x_train))[1]
sta["randomclassi"]=pd.DataFrame(rfclassifier.predict_proba(x_train))[1]
column_name=sta.columns
sta=pd.concat([sta,pd.DataFrame(y_train).reset_index(drop=True)],axis=1)

# %%
sta.head(10)
# Out:
#    decision  randomclassi  Survived
# 0  0.545455      0.519151         0
# 1  0.086957      0.098406         0
# 2  0.142857      0.140412         0
# 3  0.166667      0.176160         0
# 4  0.166667      0.192043         0
# 5  0.428571      0.438711         0
# 6  0.000000      0.181006         0
# 7  0.000000      0.005714         0
# 8  0.118644      0.119439         0
# 9  0.142857      0.144715         1

# %%
x_meta=sta.drop("Survived",axis=1)
y_meta=sta["Survived"]
x_meta
# Out:
#      decision  randomclassi
# 0    0.545455      0.519151
# 1    0.086957      0.098406
# 2    0.142857      0.140412
# 3    0.166667      0.176160
# 4    0.166667      0.192043
# ..        ...           ...
# 707  0.666667      0.676242
# 708  0.545455      0.519151
# 709  0.000000      0.000000
# 710  0.666667      0.663032
# 711  0.285714      0.286738
#
# [712 rows x 2 columns]

# %%
from sklearn.linear_model import LogisticRegression
lreg=LogisticRegression()
lreg.fit(x_meta,y_meta)
# Out:
# LogisticRegression()

# %%
lr=pd.DataFrame()
lr["decision"]=pd.DataFrame(dtclassifier.predict_proba(x_train))[1]
lr["randomclassi"]=pd.DataFrame(rfclassifier.predict_proba(x_train))[1]
lrcolumns=lr.columns
lr["combined"]=lreg.predict(lr[["decision","randomclassi"]])

# %%
lr
# Out:
#      decision  randomclassi  combined
# 0    0.545455      0.519151         1
# 1    0.086957      0.098406         0
# 2    0.142857      0.140412         0
# 3    0.166667      0.176160         0
# 4    0.166667      0.192043         0
# ..        ...           ...       ...
# 707  0.666667      0.676242         1
# 708  0.545455      0.519151         1
# 709  0.000000      0.000000         0
# 710  0.666667      0.663032         1
# 711  0.285714      0.286738         0
#
# [712 rows x 3 columns]

# %%
lrv=lr.columns
lrv2=list(lrv)
lrv.append("y_meta")
lrv2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-523987703.py in <cell line: 0>()
#       1 lrv=lr.columns
#       2 lrv2=list(lrv)
# ----> 3 lrv.append("y_meta")
#       4 lrv2
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in append(self, other)
#    5482         for obj in to_concat:
#    5483             if not isinstance(obj, Index):
# -> 5484                 raise TypeError("all inputs must be Index")
#    5485
#    5486         names = {obj.name for obj in to_concat}
#
# TypeError: all inputs must be Index

# %%
from sklearn.ensemble import StackingClassifier
estimators=[
    ("decisiontree",dtclassifier),
     ("randomclassifier",rfclassifier)
]

stac=StackingClassifier(
    estimators=estimators,
    final_estimator=lreg,
    passthrough=False
)
stac.fit(x_train,y_train)
# Out:
# StackingClassifier(estimators=[('decisiontree', DecisionTreeClassifier()),
#                                ('randomclassifier', RandomForestClassifier())],
#                    final_estimator=LogisticRegression())

# %%
evaluation(stac,x_train,y_train,x_test,y_test,train=False)
# Out:
# test result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.81      0.85      0.83       105
#            1       0.77      0.72      0.74        74
#
#     accuracy                           0.79       179
#    macro avg       0.79      0.78      0.78       179
# weighted avg       0.79      0.79      0.79       179
#
# confusionmatrix:
#  [[89 16]
#  [21 53]]

# %%
evaluation(stac,x_train,y_train,x_test,y_test,train=True)
# Out:
# train result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90       444
#            1       0.89      0.75      0.81       268
#
#     accuracy                           0.87       712
#    macro avg       0.87      0.85      0.86       712
# weighted avg       0.87      0.87      0.87       712
#
# confusionmatrix:
#  [[418  26]
#  [ 66 202]]

# %%
evaluation(dtclassifier,x_train,y_train,x_test,y_test,train=True)
# Out:
# train result:
#
# classificationreport:
#                precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90       444
#            1       0.87      0.78      0.82       268
#
#     accuracy                           0.87       712
#    macro avg       0.87      0.85      0.86       712
# weighted avg       0.87      0.87      0.87       712
#
# confusionmatrix:
#  [[413  31]
#  [ 60 208]]
